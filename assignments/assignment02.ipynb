# %% [markdown]
# # Assignment 2: Human–AI Collaboration & Code Generation/Testing
#
# **Due:** End of Week 4
# **Total Points:** 135
#
# ---
#
# ## Revision History
# - **Published — Start of Term**
#
# ---
#
# ## 1. Overview
# This assignment extends your prompt-engineering foundations into practical Human–AI collaboration: using GitHub Copilot to generate, test, and iteratively improve Java code and JUnit tests. Focus on the human–AI division of labor: when to accept suggestions, when to refine prompts, and how testing guides trustworthy acceptance.
#
# **By the end:** you'll have a test-driven Java artifact, a documented collaboration log showing prompts and decisions, and a reflective synthesis of what worked and why.
#
# ---
#
# ## 2. Alignment with the Syllabus
# - Apply Copilot to produce and refine code and tests.
# - Evaluate AI outputs for correctness, reliability, and maintainability.
# - Demonstrate reproducible prompts and transparent AI attribution.
#
# ---
#
# ## 3. Tooling & Policy (Read Carefully)
# - Approved: JDK 17+, IntelliJ or VS Code, Git, GitHub Copilot (inline + optional Chat), JUnit 5.
# - Not approved: other AI assistants for this assignment (document any exceptions with instructor).
# - Academic integrity: record prompts exactly and include an AI usage statement in `AUTHOR.md`.
#
# ---
#
# ## 4. Environment Setup (Checklist)
# 1. Use the same GitHub repo from Assignment 1.
# 2. Add `/assignment2` with `src/` and `test/` (JUnit 5).
# 3. Confirm Copilot is active and captured in screenshots (Appendix A).
# 4. Ensure tests run locally (Maven/Gradle or IDE) and include a short build instruction in README.
#
# ---
#
# ## 5. Tasks (What to do + Record)
#
# ### Task 1 — Baseline Code Selection (10 pts)
# What to do:
# - Choose an existing Java method/class (yours or an OSS snippet) and copy it into `/assignment2`.
# - Describe current behavior and identify 1–2 weaknesses to address.
# Record:
# - File path, short problem statement, and a short baseline test demonstrating the issue.
#
# ### Task 2 — Copilot Collaboration Log (20 pts)
# What to do:
# - Iteratively refactor or extend the code with Copilot.
# - For each session record prompt(s), AI suggestions, and decision (accept/modify/reject).
# Record:
# - Prompt text exactly, accepted suggestion snapshot, and short rationale for decisions.
#
# ### Task 3 — AI-Generated Class & Methods (25 pts)
# What to do:
# - Use Copilot to design a new Java class with ≥3 public methods (utility or domain model).
# - Add inline comments showing where Copilot assisted.
# Record:
# - Prompt(s) used, final code snippets, and short notes on manual edits.
#
# ### Task 4 — JUnit 5 Test Design & Coverage (25 pts)
# What to do:
# - Use Copilot to draft tests, then manually review and add missing edge-case tests.
# - Produce a coverage summary (IDE or build tool screenshot).
# Record:
# - Tests added by Copilot vs. tests you added/changed, and coverage metrics.
#
# ### Task 5 — Code Quality & Reliability Analysis (25 pts)
# What to do:
# - Evaluate generated and refined code using static analysis, complexity measures, or manual inspection.
# Record:
# - Tools used, key findings, and concrete remediation steps taken.
#
# ### Task 6 — Reflection & Synthesis (30 pts)
# What to do:
# - Write ~300 words on how Copilot changed your workflow and the ethical/reliability tradeoffs.
# Record:
# - Final reflection text and key takeaways for future collaborative workflows.
#
# ---
#
# ## 6. Deliverables & Submission
# - `/assignment2` folder with source and tests (committed to GitHub).
# - This notebook filled with prompts, code-before/after, screenshots, and reflections.
# - `AUTHOR.md` with an AI usage statement and a README with build/run instructions.
#
# ---
#
# ## 7. Report Questions (Evidence-based)
# Answer in the notebook:
# - Q1: Baseline: Why this code and what were the targeted improvements?
# - Q2: Collaboration Log: Which prompt styles yielded the best test coverage and why?
# - Q3: Tests: Which edge cases were missing in AI suggestions and how did you add them?
# - Q4: Reflection: What patterns will you reuse and which anti-patterns will you avoid?
#
# ---
#
# ## 8. Prompt Journal (template — duplicate per session)
# ### Target & Intention
# - File & location:
# - Goal (1–2 sentences):
# - Context provided (neighboring code, examples):
#
# ### Exact Prompt
# ```
# <paste exact prompt>
# ```
#
# ### Observed Completion (summary)
# - Key choices Copilot made:
# - Mismatches vs. intention:
#
# ### Iteration / Refinement Prompt
# ```
# <paste refined prompt>
# ```
# - What changed and why:
#
# ### Takeaways
# - Pattern or anti-pattern discovered:
# - What you’ll reuse next time:
#
# ---
#
# ## 9. Grading Breakdown (135 pts)
# | Category | Points |
# |---|---:|
# | Baseline Code Selection | 10 |
# | Collaboration Log | 20 |
# | AI-Generated Class & Methods | 25 |
# | Test Design & Coverage | 25 |
# | Code Quality & Reliability Analysis | 25 |
# | Reflection & Synthesis | 30 |
# | **Total** | **135** |
#
# ---
#
# ## 10. Appendix A — Screenshots
# Insert screenshots (IDE with Copilot, test runs, coverage report, Copilot settings).
#
# ---
#
# ## 11. Academic Integrity Reminder
# Attribute Copilot assistance, record prompts exactly, and ensure you understand all submitted code.
