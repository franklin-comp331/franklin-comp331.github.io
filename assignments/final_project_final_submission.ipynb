# %% [markdown]
# # Final Project Final Submission: Complete System, Documentation, Evaluation Report, and Demo
#
# **Course Name/Number:** COMP 331: AI-Assisted Software Engineering
# **Week:** 12
# **Points:** 180
#
# This final submission completes the project developed through [Final Project Milestone 1](final_project_milestone01.ipynb) and [Final Project Milestone 2](final_project_milestone02.ipynb).

# %% [markdown]
# ## Purpose of Assignment
#
# This assignment is intended to help you:
#
# - Deliver a complete integrated Controlled Coding Agent system
# - Demonstrate integration of all course components and team contributions
# - Apply engineering judgment to AI-assisted workflows
# - Demonstrate human oversight, verification, and collaborative engineering practice
# - Clearly communicate system design and results

# %% [markdown]
# ## Steps / Requirements of Assignment
#
# Finalize your Controlled Coding Agent system and submit a complete, reproducible project. Your final submission should demonstrate integration of structured input, AI-assisted generation, evaluation, controlled workflow, persistence or artifact tracking, documentation, and human oversight. Teams should show multi-component integration, shared testing workflows, collaborative AI-assisted development, and verification of AI-generated outputs through testing, peer review, static analysis, integration testing, or manual inspection.

# %% [markdown]
# ## Using GitHub Copilot
#
# Your final submission should make GitHub Copilot-assisted development transparent. Evidence should show responsible engineering judgment, not just prompt volume. Treat AI-generated code, tests, and documentation as untrusted until reviewed and validated.
#
# Add an `AI Assistance` section to your README using this structure:
#
# ```markdown
# ## AI Assistance
#
# GitHub Copilot was used for:
# - Planning:
# - Code generation:
# - Test generation:
# - Debugging:
# - Review:
#
# Important Copilot suggestions accepted:
# Important Copilot suggestions modified:
# Important Copilot suggestions rejected:
# Verification methods:
# Team AI usage practices:
# Shared verification procedures:
# Collaborative prompt engineering examples:
# Division of responsibilities:
# ```
#
# Connect this section to your weekly interaction logs, example workflow artifacts, tests, and demo.

# %% [markdown]
# ## Action Items
#
# - Click the link to the full hosted final submission instructions: [Final Project Final Submission](https://t-morgan.github.io/ai-assisted-software-engineering/assignments/final_project_final_submission.html).
# - Follow the instructions in the final submission page.
# - Open your final project repository and review all milestone feedback, known risks, and incomplete tasks.
# - Finalize the complete system, documentation, evaluation report, example workflow artifacts, team retrospective, individual reflections, and recorded demo described in the linked instructions.
# - Add an `AI Assistance` README section identifying Copilot use, accepted/modified/rejected suggestions, team AI usage practices, shared verification procedures, collaborative prompt engineering examples, division of responsibilities, and verification methods.
# - Ensure the recorded demo includes all team members and covers technical functionality, engineering workflow, Copilot assistance, and verification/quality assurance practices.
# - Include repository evidence for pull requests, reviews, contribution summaries, testing workflows, and integration.
# - Verify the project from a clean environment and confirm no secrets are committed.
# - Commit your completed work and obtain the Git commit hash for the submitted version.
# - Submit the project repository link, commit hash, and recorded demo link through Canvas.

# %% [markdown]
# ## Deliverables
#
# Your repository should include:
#
# - Complete runnable Controlled Coding Agent system.
# - README with setup, run, evaluation, demo instructions, and an `AI Assistance` section.
# - Evaluation report with results and interpretation.
# - Example workflow run artifacts.
# - Pull request/review history, contribution summaries, testing workflow evidence, and integration evidence.
# - AI-assisted development evidence focused on Copilot use, human verification, and rejected or corrected outputs.
# - Team retrospective discussing collaboration practices, asynchronous teamwork challenges, AI-assisted development strengths/limitations, verification lessons, and coordination effects on quality.
# - Individual reflection from each student summarizing contributions, AI-assisted workflow usage, verification responsibilities, lessons learned, and collaboration challenges.
# - Link to a 5-8 minute recorded team demo with participation from all team members.

# %% [markdown]
# ## Grading
#
# | Category | Points |
# |---|---:|
# | Complete team system integrates input, generation, evaluation, workflow, and persistence/artifact tracking | 50 |
# | System runs from a clean environment with clear instructions | 25 |
# | Evaluation report and testing workflow evidence are meaningful and evidence-based | 35 |
# | Documentation clearly explains architecture, usage, limitations, collaboration workflow, and responsibilities | 30 |
# | Team demo is clear, complete, includes all members, and stays within 5-8 minutes | 25 |
# | Copilot-assisted development evidence is complete, transparent, and verification-focused | 15 |
# | **Total** | **180** |

# %% [markdown]
# ## Submission Instructions
#
# Submit your project repository link and recorded demo link through Canvas. Include paths to the team retrospective, individual reflections, contribution summaries, pull request/review evidence, testing workflow evidence, integration evidence, and README `AI Assistance` section. Recommended grading emphasis is 70% team deliverables, 20% individual contributions, and 10% reflection/review participation. Submit the Git commit hash for the exact version you want graded. After committing your final work, run:
#
# ```bash
# git rev-parse HEAD
# ```
#
# Follow any additional sharing instructions provided by your professor.
